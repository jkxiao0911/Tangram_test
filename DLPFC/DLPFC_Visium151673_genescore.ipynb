# %%
import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
from anndata import AnnData
import pathlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import skimage
import seaborn as sns
import tangram as tg
import os
sc.logging.print_header()
print(f"squidpy=={sq.__version__}")

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# scanpy==1.9.3 anndata==0.9.2 umap==0.5.3 numpy==1.22.4 scipy==1.10.1 pandas==2.0.3 scikit-learn==1.3.0 statsmodels==0.14.0 python-igraph==0.10.6 pynndescent==0.5.10
# squidpy==1.2.3

# %%
section_id ='151673'    
input_dir = os.path.join('/mnt/disk1/xzhou/data/spatial_3D/DLPFC/', section_id)
adata_st = sc.read_visium(path=input_dir, count_file=section_id + '_filtered_feature_bc_matrix.h5', load_images=True)
adata_st.var_names_make_unique(join="++")

# read the annotation
Ann_df = pd.read_csv(os.path.join(input_dir, section_id + '_truth.txt'), sep='\t', header=None, index_col=0)
Ann_df.columns = ['Ground Truth']
Ann_df[Ann_df.isna()] = "unknown"
adata_st.obs['Ground Truth'] = Ann_df.loc[adata_st.obs_names, 'Ground Truth'].astype('category') 

#'Ground Truth' 是原始列名，你需要将其改为 'cell_type'
adata_st.obs.rename(columns={'Ground Truth': 'cell_type'}, inplace=True)
sc.pl.spatial(adata_st, alpha=0.7, frameon=False, show=True)

# %%
sc.pp.highly_variable_genes(adata_st, n_top_genes=2000, flavor="seurat_v3")
sc.pp.normalize_total(adata_st)
# sc.pp.log1p(adata_st)

# %%
ad_sp1 = adata_st.copy()

# %%
adata_st
# Out:
# AnnData object with n_obs × n_vars = 3639 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'cell_type'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'spatial', 'hvg', 'log1p'
#     obsm: 'spatial'

# %%
ad_sc = sc.read_h5ad("/mnt/disk1/xiaojk/data/DLPFC/GeneScoreMatrix.h5ad")

# %%
ad_sc
# Out:
# AnnData object with n_obs × n_vars = 5262 × 23127
#     obs: 'cell_type'
#     var: 'features'

# %%
ad_sc
# Out:
# AnnData object with n_obs × n_vars = 5262 × 23127
#     obs: 'cell_type'
#     var: 'features'

# %%
np.unique(ad_sc.X.toarray()[0, :])
# Out:
# array([0.0000e+00, 1.9000e-02, 2.2000e-02, ..., 1.1342e+01, 1.6189e+01,
#        3.2453e+01])

# %%
sc.pp.normalize_total(ad_sc)

# %%
ad_sc.obs['subclass_label'] = ad_sc.obs.cell_type

# %%
ad_sp1.obs.cell_type.value_counts()
# Out:
# cell_type
# Layer_3    989
# Layer_6    692
# Layer_5    673
# WM         513
# Layer_1    273
# Layer_2    253
# Layer_4    218
# unknown     28
# Name: count, dtype: int64

# %%
ad_sc.obs.subclass_label.value_counts()
# Out:
# subclass_label
# Oligo      1075
# L4          785
# L2/3        756
# Micro       713
# OPC         673
# MGE der     617
# CGE der     473
# L5/6         72
# Astro        71
# Vas          16
# PN dev       11
# Name: count, dtype: int64

# %%
adata_sc = ad_sc.copy()
adata_sc
# Out:
# AnnData object with n_obs × n_vars = 5262 × 23127
#     obs: 'cell_type', 'subclass_label'
#     var: 'features'

# %%
sc.tl.rank_genes_groups(adata_sc, groupby="subclass_label", use_raw=False)
markers_df = pd.DataFrame(adata_sc.uns["rank_genes_groups"]["names"]).iloc[0:100, :]
markers = list(np.unique(markers_df.melt().value.values))
len(markers)
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# 888

# %%
markers
# Out:
# ['AATK',
#  'ABCA13',
#  'ABCA2',
#  'ABCB5',
#  'ABCC1',
#  'ABCC4',
#  'ABI3',
#  'ABLIM1',
#  'ABR',
#  'ACSS3',
#  'ACTN1',
#  'ACVR1',
#  'ADAMTS3',
#  'ADAMTS9',
#  'ADAP1',
#  'ADARB2',
#  'ADARB2-AS1',
#  'ADCY2',
#  'ADCYAP1R1',
#  'ADGRB1',
#  'ADGRD1',
#  'ADH5',
#  'ADORA3',
#  'ADRB2',
#  'AFAP1',
#  'AFAP1L2',
#  'AFF2',
#  'AGAP1',
#  'AGBL1',
#  'AGBL4',
#  'AGMO',
#  'AHDC1',
#  'AJUBA',
#  'AKAP2',
#  'ALCAM',
#  'ALK',
#  'AMOTL1',
#  'AMOTL2',
#  'ANGPT1',
#  'ANK1',
#  'ANK2',
#  'ANXA5',
#  'APBB2',
#  'AQP4-AS1',
#  'ARAP2',
#  'ARHGAP10',
#  'ARHGAP23',
#  'ARHGAP24',
#  'ARHGAP25',
#  'ARHGAP26',
#  'ARHGAP29',
#  'ARHGAP44',
#  'ARHGEF17',
#  'ASCL1',
#  'ASIC2',
#  'ASTN2',
#  'ATG7',
#  'ATP10A',
#  'ATP13A4',
#  'ATP1A2',
#  'ATP2B2',
#  'ATP8A2',
#  'ATRNL1',
#  'AUTS2',
#  'AXIN2',
#  'B3GNT5',
#  'B3GNT7',
#  'B4GALT1',
#  'B9D1',
#  'BAIAP2',
#  'BANK1',
#  'BCAN',
#  'BCAR1',
#  'BCL11A',
#  'BCL11B',
#  'BEND4',
#  'BFSP2',
#  'BHLHA9',
#  'BIN1',
#  'BMP6',
#  'BMP7',
#  'BMPER',
#  'BRINP1',
#  'BSN',
#  'BTBD11',
#  'BTBD9',
#  'C1QL1',
#  'C1orf61',
#  'C3',
#  'C4orf45',
#  'C9orf139',
#  'C9orf3',
#  'C9orf62',
#  'CA10',
#  'CAB39L',
#  'CACNA1B',
#  'CACNA1C',
#  'CACNA1C-IT3',
#  'CACNA1D',
#  'CACNA1E',
#  'CACNA1I',
#  'CACNA2D2',
#  'CACNA2D3',
#  'CACNG2',
#  'CACNG3',
#  'CACNG4',
#  'CADPS',
#  'CADPS2',
#  'CAMK1D',
#  'CAMK2A',
#  'CAMK2B',
#  'CAMK2D',
#  'CAMTA1',
#  'CAP2',
#  'CAPZB',
#  'CARMIL1',
#  'CARMN',
#  'CAV2',
#  'CAVIN3',
#  'CCBE1',
#  'CCDC190',
#  'CCDC3',
#  'CCDC33',
#  'CCDC88C',
#  'CCR3',
#  'CCSER1',
#  'CD83',
#  'CDC42EP1',
#  'CDC7',
#  'CDH13',
#  'CDH18',
#  'CDH22',
#  'CDH23',
#  'CDH4',
#  'CDH5',
#  'CDK18',
#  'CDON',
#  'CDYL2',
#  'CEACAM21',
#  'CEBPA-DT',
#  'CELF2',
#  'CELF2-AS2',
#  'CELF4',
#  'CENPP',
#  'CEP112',
#  'CERCAM',
#  'CGNL1',
#  'CHM',
#  'CHODL',
#  'CHRM3',
#  'CHST11',
#  'CHST12',
#  'CHST3',
#  'CLDN11',
#  'CLSTN1',
#  'CLSTN2',
#  'CMYA5',
#  'CNBD1',
#  'CNTN2',
#  'CNTN4',
#  'CNTN6',
#  'CNTNAP2',
#  'CNTNAP5',
#  'COBL',
#  'COL12A1',
#  'COL18A1',
#  'COL1A2',
#  'COL20A1',
#  'COL26A1',
#  'COL4A1',
#  'COL4A2',
#  'COL5A1',
#  'COL6A1',
#  'COL6A2',
#  'COLEC12',
#  'COLGALT2',
#  'CORO2B',
#  'CPNE2',
#  'CPNE4',
#  'CPXM2',
#  'CRACR2A',
#  'CRB1',
#  'CREB5',
#  'CRTC1',
#  'CRYGN',
#  'CSF1R',
#  'CSMD1',
#  'CSMD3',
#  'CSPG4',
#  'CT62',
#  'CTNNA2',
#  'CTNNA3',
#  'CTSB',
#  'CUBN',
#  'CUEDC1',
#  'CUX2',
#  'CX3CR1',
#  'CXCL14',
#  'CXXC5',
#  'CYFIP1',
#  'CYP1B1-AS1',
#  'CYTH4',
#  'DAB1',
#  'DACH2',
#  'DAD1',
#  'DAPK1',
#  'DCC',
#  'DCLK1',
#  'DEPTOR',
#  'DGKB',
#  'DIAPH2',
#  'DIO3',
#  'DLGAP1',
#  'DLGAP4',
#  'DLX1',
#  'DLX6-AS1',
#  'DMD',
#  'DNAJB6',
#  'DOCK5',
#  'DRAIC',
#  'DSCAM',
#  'DSCAML1',
#  'DUSP27',
#  'DUSP7',
#  'EBF1',
#  'EFNA5',
#  'EGFR',
#  'EIF5AL1',
#  'EIPR1',
#  'ELAVL2',
#  'ELFN1',
#  'ELFN2',
#  'EMX2',
#  'EMX2OS',
#  'ENG',
#  'EPAS1',
#  'EPN2',
#  'EPN2-AS1',
#  'ERBB4',
#  'ERC2',
#  'ERG',
#  'ESRRB',
#  'EXOC4',
#  'EYS',
#  'FA2H',
#  'FAAH2',
#  'FAM102A',
#  'FAM135B',
#  'FAM171A1',
#  'FAM189A1',
#  'FAM19A1',
#  'FAM20A',
#  'FAM222A',
#  'FAM53B',
#  'FAM78A',
#  'FARP1',
#  'FAT3',
#  'FBXL13',
#  'FBXO31',
#  'FGD5',
#  'FGF14',
#  'FGFR2',
#  'FHL2',
#  'FMNL2',
#  'FMNL3',
#  'FOS',
#  'FOSL2',
#  'FOXC1',
#  'FOXF2',
#  'FOXP1',
#  'FOXP2',
#  'FOXQ1',
#  'FPR3',
#  'FRMD4A',
#  'FRMD4B',
#  'FRMPD4',
#  'FSTL4',
#  'FSTL5',
#  'FUK',
#  'FZD10-DT',
#  'GAB1',
#  'GABBR2',
#  'GABRB3',
#  'GABRG3',
#  'GALNT10',
#  'GALNT14',
#  'GALNT17',
#  'GALNT18',
#  'GALNT9',
#  'GALNTL6',
#  'GATA6-AS1',
#  'GATD3A',
#  'GGACT',
#  'GJD4',
#  'GLI3',
#  'GLIS1',
#  'GLUD1P2',
#  'GMDS',
#  'GNAO1',
#  'GPC3',
#  'GPC5',
#  'GPC6',
#  'GPR132',
#  'GPR17',
#  'GPR183',
#  'GPR26',
#  'GPR37',
#  'GRIA1',
#  'GRID1',
#  'GRID2',
#  'GRIK1',
#  'GRIK3',
#  'GRIK4',
#  'GRIN2A',
#  'GRIN2B',
#  'GRIP1',
#  'GRIP2',
#  'GRM1',
#  'GRM4',
#  'GRM8',
#  'GSDME',
#  'GSG1L',
#  'GSN',
#  'GTF2IRD1',
#  'GULP1',
#  'HCK',
#  'HDAC4',
#  'HDAC9',
#  'HECW1',
#  'HES5',
#  'HGFAC',
#  'HHEX',
#  'HIP1R',
#  'HIPK2',
#  'HMGA2',
#  'HPSE2',
#  'HS3ST4',
#  'HS6ST3',
#  'HUNK',
#  'ICOSLG',
#  'IER3',
#  'IFNGR1',
#  'IGF2',
#  'IGSF9B',
#  'IL10RA',
#  'IL1R1',
#  'IL1RAPL1',
#  'IL1RAPL2',
#  'IL34',
#  'INPP5D',
#  'IRF8',
#  'ISPD',
#  'ITGB2',
#  'ITIH5',
#  'ITPK1',
#  'ITPR1',
#  'ITPR2',
#  'JAKMIP1',
#  'JAKMIP3',
#  'JUNB',
#  'KALRN',
#  'KAZN',
#  'KCNB1',
#  'KCND2',
#  'KCND3',
#  'KCNE4',
#  'KCNH1',
#  'KCNIP4',
#  'KCNJ10',
#  'KCNJ12',
#  'KCNJ6',
#  'KCNK3',
#  'KCNK5',
#  'KCNMA1',
#  'KCNQ2',
#  'KCNQ5',
#  'KCNT1',
#  'KCTD12',
#  'KCTD16',
#  'KHDRBS2',
#  'KHDRBS3',
#  'KIAA1211L',
#  'KIAA1217',
#  'KIAA1328',
#  'KIAA1549L',
#  'KIAA1671',
#  'KIAA2012',
#  'KIF26A',
#  'KIF26B',
#  'KIRREL1',
#  'KIRREL3',
#  'KLF2',
#  'KLHL29',
#  'KSR2',
#  'LAMA1',
#  'LAMA4',
#  'LARGE-AS1',
#  'LARGE1',
#  'LCNL1',
#  'LDB2',
#  'LEF1',
#  'LHFPL2',
#  'LHFPL3',
#  'LHX6',
#  'LIMS2',
#  'LIN7A',
#  'LINC00226',
#  'LINC00351',
#  'LINC00476',
#  'LINC00499',
#  'LINC00536',
#  'LINC00615',
#  'LINC00673',
#  'LINC00871',
#  'LINC00911',
#  'LINC00922',
#  'LINC00963',
#  'LINC01016',
#  'LINC01126',
#  'LINC01270',
#  'LINC01446',
#  'LINC01501',
#  'LINC01600',
#  'LINC01622',
#  'LINC01959',
#  'LINC02291',
#  'LINGO1',
#  'LINGO1-AS1',
#  'LINGO2',
#  'LIPA',
#  'LMF1',
#  'LMX1B',
#  'LOC100128239',
#  'LOC100130238',
#  'LOC100506207',
#  'LOC286083',
#  'LOC401557',
#  'LOC643441',
#  'LPAR5',
#  'LPCAT1',
#  'LRFN2',
#  'LRFN5',
#  'LRMDA',
#  'LRP1',
#  'LRP5',
#  'LRP8',
#  'LRRC17',
#  'LRRIQ1',
#  'LRRIQ3',
#  'LRRN2',
#  'LRRTM4',
#  'LYL1',
#  'LZTS1-AS1',
#  'MACROD2',
#  'MAD1L1',
#  'MAG',
#  'MAL',
#  'MAPK10',
#  'MAPK4',
#  'MARCH1',
#  'MAST4',
#  'MBP',
#  'MCF2L2',
#  'MEF2C',
#  'MEGF11',
#  'MEIS3',
#  'MERTK',
#  'METTL24',
#  'MGAT4C',
#  'MGAT5B',
#  'MGMT',
#  'MICAL2',
#  'MIDN',
#  'MIPOL1',
#  'MIR100HG',
#  'MIR1231',
#  'MIR1275',
#  'MIR1289-2',
#  'MIR1537',
#  'MIR338',
#  'MIR3935',
#  'MIR3938',
#  'MIR4266',
#  'MIR4510',
#  'MIR4534',
#  'MIR548AN',
#  'MIR548F1',
#  'MIR548F5',
#  'MIR548I4',
#  'MIR5584',
#  'MIR595',
#  'MIR618',
#  'MIR657',
#  'MIR885',
#  'MIR9-3HG',
#  'MIRLET7BHG',
#  'MKNK1',
#  'MLF2',
#  'MMD2',
#  'MMRN1',
#  'MOB3B',
#  'MPPED1',
#  'MRGPRF',
#  'MROH5',
#  'MROH7-TTC4',
#  'MSI2',
#  'MSRA',
#  'MTMR7',
#  'MTSS1L',
#  'MTUS2',
#  'MVB12B',
#  'MYH15',
#  'MYO18B',
#  'MYO5B',
#  'MYRF',
#  'MYT1',
#  'MYT1L',
#  'NAALADL2',
#  'NAV1',
#  'NEBL',
#  'NEGR1',
#  'NELL1',
#  'NELL2',
#  'NEU4',
#  'NEURL1',
#  'NFATC4',
#  'NFIB',
#  'NFIC',
#  'NFIX',
#  'NINJ1',
#  'NKAIN2',
#  'NKD1',
#  'NKX2-2',
#  'NMNAT2',
#  'NOS1',
#  'NOTCH1',
#  'NPAS3',
#  'NPTX2',
#  'NR5A2',
#  'NRG1',
#  'NRG3',
#  'NRN1',
#  'NRXN3',
#  'NTN1',
#  'NTRK2',
#  'NTRK3',
#  'NUDT3',
#  'NWD2',
#  'NXPH1',
#  'NYAP2',
#  'OBSCN',
#  'OCA2',
#  'ODF3B',
#  'ODF3L2',
#  'OLFM1',
#  'OLIG1',
#  'OLIG2',
#  'OPCML',
#  'OPRD1',
#  'OR13H1',
#  'OSBPL5',
#  'OSM',
#  'OTULINL',
#  'P2RY12',
#  'PACRG',
#  'PACSIN1',
#  'PALD1',
#  'PANK4',
#  'PARD3',
#  'PARD3B',
#  'PARVA',
#  'PAX2',
#  'PCCA',
#  'PCDH15',
#  'PCDHGA1',
#  'PCDHGA10',
#  'PCDHGA11',
#  'PCDHGA12',
#  'PCDHGA2',
#  'PCDHGA3',
#  'PCDHGA4',
#  'PCDHGA5',
#  'PCDHGA6',
#  'PCDHGA7',
#  'PCDHGA8',
#  'PCDHGA9',
#  'PCDHGB1',
#  'PCDHGB2',
#  'PCDHGB3',
#  'PCDHGB4',
#  'PCDHGB5',
#  'PCDHGB6',
#  'PCDHGB7',
#  'PCDHGC3',
#  'PCDHGC4',
#  'PCDHGC5',
#  'PCLO',
#  'PCP4',
#  'PDE10A',
#  'PDE11A',
#  'PDE3A',
#  'PDE4D',
#  'PDGFB',
#  'PDGFRB',
#  'PDZRN3',
#  'PHACTR1',
#  'PHLDB2',
#  'PHLPP1',
#  'PHYHIP',
#  'PICK1',
#  'PIK3AP1',
#  'PILRA',
#  'PIP4K2A',
#  'PITPNC1',
#  'PITPNM3',
#  'PKHD1',
#  'PKNOX2',
#  'PLA2R1',
#  'PLCB1',
#  'PLEKHG2',
#  'PLEKHG3',
#  'PLG',
#  'PLLP',
#  'PLXNA4',
#  'PMEPA1',
#  'POLR2F',
#  'POU3F2',
#  'POU6F2',
#  'PPARGC1A',
#  'PPFIBP2',
#  'PPM1H',
#  'PPM1J',
#  'PPP1R14A',
#  'PPP2R2C',
#  'PRDM16',
#  'PREX1',
#  'PRKAG2',
#  'PRKCB',
#  'PRKCE',
#  'PRKN',
#  'PRLHR',
#  'PRR32',
#  'PSAPL1',
#  'PTCHD1-AS',
#  'PTGDS',
#  'PTGER3',
#  'PTH2R',
#  'PTMA',
#  'PTPA',
#  'PTPN20',
#  'PTPRD',
#  'PTPRG',
#  'PTPRM',
#  'PTPRN2',
#  'PTPRT',
#  'PYGO1',
#  'RAB20',
#  'RALYL',
#  'RAP1GAP',
#  'RAPGEF1',
#  'RAPGEF3',
#  'RASGEF1C',
#  'RASGRF2',
#  'RBFOX1',
#  'RBFOX3',
#  'RBMS3',
#  'RBPMS',
#  'RECQL5',
#  'RFPL4B',
#  'RFTN1',
#  'RGS10',
#  'RGS12',
#  'RGS20',
#  'RGS3',
#  'RGS6',
#  'RGS7',
#  'RGS8',
#  'RHBDF2',
#  'RHBDL3',
#  'RIMBP2',
#  'RIMS4',
#  'RIN2',
#  'RIPOR2',
#  'RNF220',
#  'RNF5P1',
#  'ROBO2',
#  'RORA',
#  'RPH3A',
#  'RPL3',
#  'RPS6KA2',
#  'RPTOR',
#  'RREB1',
#  'RUNX1',
#  'RXRA',
#  'RYR2',
#  'S1PR1',
#  'SALL3',
#  'SARS',
#  'SASH1',
#  'SATB2',
#  'SCD5',
#  'SDK1',
#  'SEMA3A',
#  'SEMA3B',
#  'SEMA6A',
#  'SEPT4',
#  'SERGEF',
#  'SERPINH1',
#  'SETBP1',
#  'SEZ6L',
#  'SFMBT2',
#  'SFTA1P',
#  'SFTPC',
#  'SFXN5',
#  'SGCZ',
#  'SH2B3',
#  'SH3BP2',
#  'SH3GL2',
#  'SH3RF3',
#  'SH3TC1',
#  'SHANK1',
#  'SHANK2',
#  'SHB',
#  'SHISA9',
#  'SIAH3',
#  'SIK3',
#  'SLC16A3',
#  'SLC1A2',
#  'SLC24A2',
#  'SLC24A3',
#  'SLC25A21',
#  'SLC30A10',
#  'SLC32A1',
#  'SLC39A13',
#  'SLC43A2',
#  'SLC6A11',
#  'SLC6A13',
#  'SLC6A17',
#  'SLC9A9',
#  'SLC9C2',
#  'SLCO2A1',
#  'SLCO2B1',
#  'SLIT1',
#  'SLIT3',
#  'SMAD6',
#  'SMG6',
#  'SMOC1',
#  'SMYD3',
#  'SNORD109B',
#  'SOCS6',
#  'SORBS1',
#  'SORBS2',
#  'SORCS2',
#  'SORCS3',
#  'SORL1',
#  'SOX1',
#  'SOX13',
#  'SOX2-OT',
#  'SOX21',
#  'SOX8',
#  'SPAG16',
#  'SPAG17',
#  'SPATS1',
#  'SPHKAP',
#  'SPOCK1',
#  'SPPL2B',
#  'SRGN',
#  'SRPX',
#  'SRRM4',
#  'SSBP3',
#  'ST18',
#  'ST6GAL1',
#  'ST6GALNAC5',
#  'STC2',
#  'STIL',
#  'STK3',
#  'STK32B',
#  'STK39',
#  'STON2',
#  'STXBP5L',
#  'SUGCT',
#  'SUGP1',
#  'SULF2',
#  'SV2B',
#  'SV2C',
#  'SVIL',
#  'SYNPO',
#  'SYNPR',
#  'SYT1',
#  'SYT7',
#  'TAB2',
#  'TAL1',
#  'TBC1D21',
#  'TBC1D22A',
#  'TBX3',
#  'TDRP',
#  'TENM1',
#  'TENM2',
#  'TENM3',
#  'TENM4',
#  'TEX44',
#  'TFEB',
#  'TGFB1',
#  'TGFBR3',
#  'THADA',
#  'THEG',
#  'THSD4',
#  'THSD7A',
#  'THSD7B',
#  'TIAM1',
#  'TINAGL1',
#  'TMCC2',
#  'TMEM132C',
#  'TMEM132D',
#  'TMEM178B',
#  'TMEM204',
#  'TMEM235',
#  'TMEM63A',
#  'TMTC2',
#  'TNFRSF11B',
#  'TNFRSF1B',
#  'TNK2',
#  'TNR',
#  'TNS1',
#  'TNS3',
#  'TOGARAM2',
#  'TOX2',
#  'TPCN2',
#  'TPK1',
#  'TPPP',
#  'TRAPPC9',
#  'TRDN',
#  'TRMT44',
#  'TSHZ2',
#  'TSHZ3',
#  'TSPAN14',
#  'TSPAN9',
#  'TTC28',
#  'TTYH3',
#  'UACA',
#  'UBAC2',
#  'UBASH3B',
#  'ULK4',
#  'UNC13B',
#  'UNC13D',
#  'UNC5A',
#  'UNC5C',
#  'UPB1',
#  'URM1',
#  'USH2A',
#  'USP26',
#  'UTRN',
#  'VAC14',
#  'VAV2',
#  'VCAN',
#  'VIPR1',
#  'VSIR',
#  'WDR20',
#  'WDR86-AS1',
#  'WEE1',
#  'WSCD1',
#  'WSCD2',
#  'WWC2-AS2',
#  'WWTR1',
#  'XIRP2',
#  'XKR4',
#  'XKR6',
#  'XXYLT1',
#  'XXYLT1-AS2',
#  'XYLT1',
#  'YBX3',
#  'YY1P2',
#  'ZBTB16',
#  'ZBTB20',
#  'ZBTB7C',
#  'ZCCHC24',
#  'ZEB2',
#  'ZFHX3',
#  'ZFHX4',
#  'ZFP36L1',
#  'ZIC2',
#  'ZIC4',
#  'ZIC5',
#  'ZMAT4',
#  'ZNF385B',
#  'ZNF536',
#  'ZNF710',
#  'ZNRF4']

# %%
tg.pp_adatas(adata_sc, adata_st, genes=markers)
# Out:
# INFO:root:807 training genes are saved in `uns``training_genes` of both single cell and spatial Anndatas.
# INFO:root:17100 overlapped genes are saved in `uns``overlap_genes` of both single cell and spatial Anndatas.
# INFO:root:uniform based density prior is calculated and saved in `obs``uniform_density` of the spatial Anndata.
# INFO:root:rna count based density prior is calculated and saved in `obs``rna_count_based_density` of the spatial Anndata.

# %%
adata_st.obs["uniform_density"]
# Out:
# AAACAAGTATCTCCCA-1    0.000275
# AAACAATCTACTAGCA-1    0.000275
# AAACACCAATAACTGC-1    0.000275
# AAACAGAGCGACTCCT-1    0.000275
# AAACAGCTTTCAGAAG-1    0.000275
#                         ...
# TTGTTTCACATCCAGG-1    0.000275
# TTGTTTCATTAGTCTA-1    0.000275
# TTGTTTCCATACAACT-1    0.000275
# TTGTTTGTATTACACG-1    0.000275
# TTGTTTGTGTAAATTC-1    0.000275
# Name: uniform_density, Length: 3639, dtype: float64

# %%
assert adata_sc.uns['training_genes'] == adata_st.uns['training_genes']

# %%
ad_map = tg.map_cells_to_space(adata_sc, adata_st,
    mode="cells",
#     mode="clusters",
#     cluster_label='cell_subclass',  # .obs field w cell types
    density_prior='rna_count_based',
    num_epochs=500,
    device="cuda:1",
#     device='cpu',
)
# Out:
# INFO:root:Allocate tensors for mapping.
# INFO:root:Begin training with 807 genes and rna_count_based density_prior in cells mode...
# INFO:root:Printing scores every 100 epochs.
# Score: 0.299, KL reg: 0.009
# Score: 0.474, KL reg: 0.002
# Score: 0.480, KL reg: 0.002
# Score: 0.482, KL reg: 0.002
# Score: 0.482, KL reg: 0.002
# INFO:root:Saving results..

# %%
ad_map
# Out:
# AnnData object with n_obs × n_vars = 5262 × 3639
#     obs: 'cell_type', 'subclass_label'
#     var: 'in_tissue', 'array_row', 'array_col', 'cell_type', 'uniform_density', 'rna_count_based_density'
#     uns: 'train_genes_df', 'training_history'

# %%
ad_sp1
# Out:
# AnnData object with n_obs × n_vars = 3639 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'cell_type'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'spatial', 'hvg', 'log1p'
#     obsm: 'spatial'

# %%
def construct_obs_plot(df_plot, adata, perc=0, suffix=None):
    # clip
    df_plot = df_plot.clip(df_plot.quantile(perc), df_plot.quantile(1 - perc), axis=1)

    # normalize
    df_plot = (df_plot - df_plot.min()) / (df_plot.max() - df_plot.min())

    if suffix:
        df_plot = df_plot.add_suffix(" ({})".format(suffix))
    adata.obs = pd.concat([adata.obs, df_plot], axis=1)
    
    
def plot_cell_annotation_sc(
    adata_sp, 
    annotation_list, 
    x="x", 
    y="y", 
    spot_size=None, 
    scale_factor=None, 
    perc=0,
    alpha_img=1.0,
    bw=False,
    ax=None
):
        
    # remove previous df_plot in obs
    adata_sp.obs.drop(annotation_list, inplace=True, errors="ignore", axis=1)

    # construct df_plot
    df = adata_sp.obsm["tangram_ct_pred"][annotation_list]
    construct_obs_plot(df, adata_sp, perc=perc)
    
    #non visium data 
    if 'spatial' not in adata_sp.obsm.keys():
        #add spatial coordinates to obsm of spatial data 
        coords = [[x,y] for x,y in zip(adata_sp.obs[x].values,adata_sp.obs[y].values)]
        adata_sp.obsm['spatial'] = np.array(coords)
    
    if 'spatial' not in adata_sp.uns.keys() and spot_size == None and scale_factor == None:
        raise ValueError("Spot Size and Scale Factor cannot be None when ad_sp.uns['spatial'] does not exist")
    
    #REVIEW
    if 'spatial' in adata_sp.uns.keys() and spot_size != None and scale_factor != None:
        raise ValueError("Spot Size and Scale Factor should be None when ad_sp.uns['spatial'] exists")
    
    sc.pl.spatial(
        adata_sp, color=annotation_list, cmap="viridis", show=False, frameon=False, spot_size=spot_size,
        scale_factor=scale_factor, alpha_img=alpha_img, bw=bw, ax=ax,colorbar_loc=None,ncols=5,wspace=0
    )

    adata_sp.obs.drop(annotation_list, inplace=True, errors="ignore", axis=1)

# %%
list(ad_sc.obs.subclass_label.unique())
# Out:
# ['MGE der',
#  'L2/3',
#  'L4',
#  'PN dev',
#  'CGE der',
#  'Astro',
#  'L5/6',
#  'Oligo',
#  'OPC',
#  'Micro',
#  'Vas']

# %%
tg.project_cell_annotations(ad_map, adata_st, annotation="subclass_label")
annotation_list = ['L2/3','L4','L5/6','Oligo','OPC']

sc.settings.set_figure_params(frameon=True, fontsize=15, facecolor='white', figsize=(2, 2)) #dpi=300, 
plot_cell_annotation_sc(adata_st,['L2/3', 'L4', 'OPC', 'L5/6'],perc=0.02, spot_size= 150)
# plot_cell_annotation_sc(adata_st,annotation_list,perc=0.02, spot_size= 150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c49c303d936> in <module>
# ----> 1 tg.project_cell_annotations(ad_map, adata_st, annotation="subclass_label")
#       2 annotation_list = ['L2/3','L4','L5/6','Oligo','OPC']
#       3
#       4 sc.settings.set_figure_params(frameon=True, fontsize=15, facecolor='white', figsize=(2, 2)) #dpi=300,
#       5 plot_cell_annotation_sc(adata_st,['L2/3', 'L4', 'OPC', 'L5/6'],perc=0.02, spot_size= 150)
#
# NameError: name 'tg' is not defined

# %%
annotation_list = ['L2/3','L4','L5/6','Oligo','OPC','MGE der','PN dev','CGE der','Astro','Micro']
sc.settings.set_figure_params(frameon=True, fontsize=15, facecolor='white',figsize=(2, 2)) #dpi=300, 
# import tangram as tg
# plot_cell_annotation_sc(rna, annotation_list, x='x', y='y', spot_size= 60, scale_factor=0.1, perc=0.001)
plot_cell_annotation_sc(adata_st, annotation_list, x='x', y='y',spot_size=200, perc=0.001)

# %%
tg.plot_training_scores(ad_map, bins=20, alpha=.5)

# %%
ad_ge = tg.project_genes(adata_map=ad_map, adata_sc=adata_sc)
ad_ge
# Out:
# AnnData object with n_obs × n_vars = 3639 × 22883
#     obs: 'in_tissue', 'array_row', 'array_col', 'cell_type', 'uniform_density', 'rna_count_based_density'
#     var: 'features', 'n_cells', 'sparsity', 'is_training'
#     uns: 'rank_genes_groups', 'training_genes', 'overlap_genes'

# %%
ad_map
# Out:
# AnnData object with n_obs × n_vars = 5262 × 3639
#     obs: 'cell_type', 'subclass_label'
#     var: 'in_tissue', 'array_row', 'array_col', 'cell_type', 'uniform_density', 'rna_count_based_density'
#     uns: 'train_genes_df', 'training_history'
